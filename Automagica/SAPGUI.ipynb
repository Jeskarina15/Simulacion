# %% [markdown]
# **SAP GUI**
#
# Click del raton
#
# Hace clic en un elemento según la ID del elemento (visión) o la posición del píxel determinada por las coordenadas x e y.

# %%
from automagica import *

recorder()
# Out:
# Launching Automagica Recorder

# %% [markdown]
# ![CapturaSAPGUI.JPG](attachment:CapturaSAPGUI.JPG)

# %% [markdown]
# Parámetros:
# - element_id: ID del elemento. Para definir un elemento y adjuntar una ID, se puede usar la grabadora Automagica. La grabadora utiliza la visión para detectar un elemento y puede invocarse con la función grabadora ().
# - x - X-coördinate
# - y - Y-coördinate
# - retraso: retraso entre clics en segundos, el valor estándar es de 100 ms.
#
# click(x=100, y=100)
