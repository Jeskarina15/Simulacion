# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
from sklearn.metrics import mean_squared_error
from scipy.optimize import curve_fit
from scipy.optimize import fsolve
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures 
url = 'C:/Users/china/Downloads/descarga.csv'

df = pd.read_csv(url)
filtro = df["Manabí"][20:]
filtro
# Out:
# 20       2
# 21       3
# 22       4
# 23       5
# 24       8
# 25       8
# 26      14
# 27      21
# 28      29
# 29      46
# 30      72
# 31      97
# 32     109
# 33     129
# 34     157
# 35     181
# 36     207
# 37     231
# 38     255
# 39     285
# 40     302
# 41     332
# 42     365
# 43     384
# 44     407
# 45     424
# 46     458
# 47     490
# 48     517
# 49     544
# 50     552
# 51     578
# 52     607
# 53     627
# 54     655
# 55     697
# 56     726
# 57     741
# 58     760
# 59     790
# 60     810
# 61     826
# 62     839
# 63     866
# 64     897
# 65     949
# 66     970
# 67     987
# 68    1011
# 69    1025
# 70    1036
# 71    1044
# 72    1044
# 73    1045
# 74    1046
# Name: Manabí, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df.plot(ax=ax)

# %%
##TASA DE CRECIMIENTO POBLACIONAL= 
#(poblacion al final del periodo-poblacion al principio del periodo)/poblacion al principio del periodo
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
from scipy.integrate import odeint

def loss(point, data, s0, i0, r0):
    size = len(data)
    beta, gamma = point
    def SIR(t, y):
        S = y[0]
        I = y[1]
        R = y[2]
        return [-beta*S*I, beta*S*I-gamma*I, gamma*I]
    solution = solve_ivp(SIR, [0, size], [s0,i0,r0], t_eval=np.arange(0, size, 1), vectorized=True)
    return np.sqrt(np.mean((solution.y[1] - data)**2))
i0=2
r0=10
s0=1788
x=np.array(range(0,55))
filtro = df["Manabí"][20:]
data= filtro
optimal = minimize(loss, [0.001, 0.001], args=(data,s0,i0, r0), method='L-BFGS-B', bounds=[(0.00001,0.4), (0.00001, 0.4)])   
beta, gamma = optimal.x
R0= (beta/gamma)*1500
print("Tasa de crecimiento epidemiologico en manabí")
print(R0)
# Out:
# Tasa de crecimiento epidemiologico en manabí
# 5.550636786105792

# %%
import simpy
import random
import matplotlib.pyplot as pp


#Numero de camas en Manabí
NUM_CAMAS=2000
#Tiempo de consulta = 17min
TIEMPO_CONSULTA=17
#Dias de simulacion = 30
DIAS_SIMULACION=300
#intervalo de llegada de los pacientes 10
INTERVALO_LLEGADA=3
#Cantidad de medicos=93
CANTIDAD_MEDICOS=12000

#COSTO POR PACIENTE= 300$ PRUEBAS ASIGNADAS POR EL MINISTERIO 80$ PRUEBAS A PERSONAS PARTICULARES 180$
COSTO_PACIENTE=80
#RECURSOS/INSUMOS POR DIA PARA UN PACIENTE:
#BATAS=25 unidades
#MASCARILLAS= 25 unididades
#EPP= 1 unidad
#GUANTES= 50 unidades
#PROTECCION OCULAR=1 unidad
#TOTAL DE RECURSOS POR HOSPITAL
TOTAL_RECURSOS=102
TOTAL=1224000
#ROJO= Signos y sintomas graves 50
#AMARILLO = Presencia de sintomas30
#VERDE= Sin factor de riesgo 20


#POBLACION DE MANABI
#NIÑOS=490451
#ADOLESCENTES=129727
#ADULTOS Y ADULTOS MAYORES=750265
#TOTAL=1370443
#INFECTADOS=1046
#POBLACION CON RIESGO DE INFECCION=1369397
MAX_PERSONAS=1369397
#PORCENTAJES EN FASCICULO DE POBLACION
#NIÑOS=35%
#ADOLESCENTES=11%
#ADULTOS Y ADULTOS MAYORES=54%

tiempo={}
riesgo=0
tiempo_atencion={}
adultoM_fallecidas={}
adulto_fallecidas={}
ninio_fallecidas={}
personas_atendidas={}
class AtencionPacientes(object):
    def __init__(self, env, num_cama):
        self.env = env
        self.num_cama = num_cama
        self.camas = simpy.Resource(env, num_cama)
        
    def atender_paciente(self, paciente):
        personas_atendidas[env.now]=paciente
        yield self.env.timeout(random.randint(TIEMPO_CONSULTA-2, TIEMPO_CONSULTA+2))
        print("El paciente se termino de atender: ", paciente, " tiempo de salida: ", self.env.now)
        tiempo_atencion[paciente]=env.now
        
def Ingreso_Paciente(env, paciente, consulta):
    llegada= env.now
    poblacion= random.randint(1,100)
    print('Ingreso del paciente con Covid-19 %s a la hora %.2f.' % (paciente, env.now))
    riesgo=random.randint(1,100)
 
    if(riesgo>40):
        with consulta.camas.request() as cama:
            yield env.process(consulta.atender_paciente(paciente))
            print('Paciente [%s] a finalizado la consulta a las %.2f.' % (paciente, env.now))
            tiempo[paciente]=env.now
            dias_esperando = random.randint(1,2) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando) #Asignar un tiempo de espera
            wait = env.now - llegada
            if cama in requerimiento:
                print("Al paciente: ", paciente, " adulto mayor en estado ROJO se le asigna una CAMA ")
                dias_hospitalizado = random.randint(1,100)
                if(dias_hospitalizado>40):
                    adultoM_fallecidas[env.now]=adultoM_fallecidas[env.now]+ 1 if env.now in adultoM_fallecidas else  1
                    print("El paciente ",paciente,"adulto mayor fallece")
                else:
                    print("El paciente ",paciente," adulto mayor pasa a un estado VERDE y se recupera de COVID-19")
                    
    elif(riesgo>20 and riesgo <40):
         with consulta.camas.request() as cama:
            yield env.process(consulta.atender_paciente(paciente))
            print('Paciente [%s] a finalizado la consulta a las %.2f.' % (paciente, env.now))
            tiempo[paciente]=env.now
            dias_esperando = random.randint(1,5) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando) #Asignar un tiempo de espera
            wait = env.now - llegada
            if cama in requerimiento:
                print("Al paciente: ", paciente, " adulto  en estado AMARILLO se le asigna una CAMA ")
                dias_hospitalizado = random.randint(1,100)
                if(dias_hospitalizado>30):
                    print("El paciente: ", paciente, " pasa a un estado ROJO")
                    dias_hospitalizado = random.randint(1,100)
                    if(dias_hospitalizado>40):
                        adulto_fallecidas[env.now]=adulto_fallecidas[env.now]+ 1 if env.now in adulto_fallecidas else  1
                        print("El paciente ",paciente,"adulto fallece")
                    else:
                        print("El paciente ",paciente,"adulto pasa a un estado VERDE y se recupera de COVID-19")
                else:
                    print("El paciente ",paciente,"adulto pasa a un estado VERDE y se recupera de COVID-19")
    else:
        with consulta.camas.request() as cama:
            yield env.process(consulta.atender_paciente(paciente))
            print('Paciente [%s] a finalizado la consulta a las %.2f.' % (paciente, env.now))
            tiempo[paciente]=env.now
            
            riesgo = random.randint(1,5)
            if (riesgo>3):
                print("Al paciente: ", paciente, " es un niño y se le asigna una CAMA ")
                dias_hospitalizado = random.randint(1,100)
                if(dias_hospitalizado>50):
                    print("El paciente: ", paciente, " es un niño y pasa a un estado ROJO")
                    dias_hospitalizado = random.randint(1,100)
                    if(dias_hospitalizado>60):
                        ninio_fallecidas[env.now]=ninio_fallecidas[env.now]+ 1 if env.now in ninio_fallecidas else  1
                    else:
                        print("El paciente ",paciente,"es un niño y pasa a un estado VERDE y se recupera de COVID-19")
                else:
                    print("El paciente ",paciente,"es un niño pasa a un estado VERDE y se recupera de COVID-19")
            else:
                print("El niño no tiene COVID-19:",paciente)

def ejecutar(env, intervalo_llegada, max_personas):
    consulta=AtencionPacientes(env, NUM_CAMAS)
    for i in range(max_personas):
        env.process(Ingreso_Paciente(env,i, consulta))
        while True:
            yield env.timeout(random.randint(intervalo_llegada-2, intervalo_llegada+2))
            i+=1
            env.process(Ingreso_Paciente(env,i, consulta))
        
env=simpy.Environment()
Tasa_de_crecimiento=round(R0)
env.process(ejecutar(env,Tasa_de_crecimiento,MAX_PERSONAS))

env.run(until =DIAS_SIMULACION)
print("Adultos mayores fallecidas: ")
print(adultoM_fallecidas)
print("Adultos fallecidos: ")
print(adulto_fallecidas)
print("Niños fallecidos: ")
print(ninio_fallecidas)
# Out:
# Ingreso del paciente con Covid-19 0 a la hora 0.00.
# Ingreso del paciente con Covid-19 1 a la hora 4.00.
# Ingreso del paciente con Covid-19 2 a la hora 12.00.
# Ingreso del paciente con Covid-19 3 a la hora 17.00.
# El paciente se termino de atender:  0  tiempo de salida:  19
# Paciente [0] a finalizado la consulta a las 19.00.
# Al paciente:  0  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente:  0  pasa a un estado ROJO
# El paciente  0 adulto fallece
# El paciente se termino de atender:  1  tiempo de salida:  21
# Paciente [1] a finalizado la consulta a las 21.00.
# Al paciente:  1  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente  1 adulto pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 4 a la hora 24.00.
# El paciente se termino de atender:  2  tiempo de salida:  30
# Paciente [2] a finalizado la consulta a las 30.00.
# Al paciente:  2  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente  2 adulto pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 5 a la hora 32.00.
# El paciente se termino de atender:  3  tiempo de salida:  34
# Paciente [3] a finalizado la consulta a las 34.00.
# Al paciente:  3  es un niño y se le asigna una CAMA
# El paciente:  3  es un niño y pasa a un estado ROJO
# El paciente  3 es un niño y pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 6 a la hora 38.00.
# El paciente se termino de atender:  4  tiempo de salida:  40
# Paciente [4] a finalizado la consulta a las 40.00.
# Al paciente:  4  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  4  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 7 a la hora 46.00.
# El paciente se termino de atender:  5  tiempo de salida:  47
# Paciente [5] a finalizado la consulta a las 47.00.
# Al paciente:  5  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  5 adulto mayor fallece
# Ingreso del paciente con Covid-19 8 a la hora 50.00.
# El paciente se termino de atender:  6  tiempo de salida:  56
# Ingreso del paciente con Covid-19 9 a la hora 56.00.
# Paciente [6] a finalizado la consulta a las 56.00.
# El niño no tiene COVID-19: 6
# El paciente se termino de atender:  7  tiempo de salida:  62
# Ingreso del paciente con Covid-19 10 a la hora 62.00.
# Paciente [7] a finalizado la consulta a las 62.00.
# Al paciente:  7  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  7  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  8  tiempo de salida:  66
# Ingreso del paciente con Covid-19 11 a la hora 66.00.
# Paciente [8] a finalizado la consulta a las 66.00.
# Al paciente:  8  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  8 adulto mayor fallece
# Ingreso del paciente con Covid-19 12 a la hora 70.00.
# El paciente se termino de atender:  9  tiempo de salida:  73
# Paciente [9] a finalizado la consulta a las 73.00.
# El niño no tiene COVID-19: 9
# Ingreso del paciente con Covid-19 13 a la hora 75.00.
# El paciente se termino de atender:  10  tiempo de salida:  78
# Paciente [10] a finalizado la consulta a las 78.00.
# Al paciente:  10  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente  10 adulto pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 14 a la hora 79.00.
# El paciente se termino de atender:  11  tiempo de salida:  81
# Paciente [11] a finalizado la consulta a las 81.00.
# Al paciente:  11  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente:  11  pasa a un estado ROJO
# El paciente  11 adulto fallece
# Ingreso del paciente con Covid-19 15 a la hora 84.00.
# El paciente se termino de atender:  12  tiempo de salida:  86
# Paciente [12] a finalizado la consulta a las 86.00.
# Al paciente:  12  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente  12 adulto pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  13  tiempo de salida:  92
# Ingreso del paciente con Covid-19 16 a la hora 92.00.
# Paciente [13] a finalizado la consulta a las 92.00.
# Al paciente:  13  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  13  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  14  tiempo de salida:  94
# Paciente [14] a finalizado la consulta a las 94.00.
# Al paciente:  14  es un niño y se le asigna una CAMA
# El paciente  14 es un niño pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  15  tiempo de salida:  99
# Paciente [15] a finalizado la consulta a las 99.00.
# El niño no tiene COVID-19: 15
# Ingreso del paciente con Covid-19 17 a la hora 100.00.
# Ingreso del paciente con Covid-19 18 a la hora 107.00.
# El paciente se termino de atender:  16  tiempo de salida:  108
# Paciente [16] a finalizado la consulta a las 108.00.
# Al paciente:  16  es un niño y se le asigna una CAMA
# El paciente:  16  es un niño y pasa a un estado ROJO
# Ingreso del paciente con Covid-19 19 a la hora 112.00.
# Ingreso del paciente con Covid-19 20 a la hora 116.00.
# El paciente se termino de atender:  17  tiempo de salida:  119
# Paciente [17] a finalizado la consulta a las 119.00.
# Al paciente:  17  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  17  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 21 a la hora 124.00.
# El paciente se termino de atender:  18  tiempo de salida:  126
# Paciente [18] a finalizado la consulta a las 126.00.
# Al paciente:  18  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente  18 adulto pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  19  tiempo de salida:  128
# Ingreso del paciente con Covid-19 22 a la hora 128.00.
# Paciente [19] a finalizado la consulta a las 128.00.
# Al paciente:  19  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente:  19  pasa a un estado ROJO
# El paciente  19 adulto pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  20  tiempo de salida:  131
# Paciente [20] a finalizado la consulta a las 131.00.
# Al paciente:  20  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  20 adulto mayor fallece
# Ingreso del paciente con Covid-19 23 a la hora 136.00.
# El paciente se termino de atender:  21  tiempo de salida:  140
# Paciente [21] a finalizado la consulta a las 140.00.
# Al paciente:  21  es un niño y se le asigna una CAMA
# El paciente  21 es un niño pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 24 a la hora 142.00.
# El paciente se termino de atender:  22  tiempo de salida:  147
# Ingreso del paciente con Covid-19 25 a la hora 147.00.
# Paciente [22] a finalizado la consulta a las 147.00.
# El niño no tiene COVID-19: 22
# El paciente se termino de atender:  23  tiempo de salida:  151
# Paciente [23] a finalizado la consulta a las 151.00.
# Al paciente:  23  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  23 adulto mayor fallece
# Ingreso del paciente con Covid-19 26 a la hora 154.00.
# El paciente se termino de atender:  24  tiempo de salida:  159
# Ingreso del paciente con Covid-19 27 a la hora 159.00.
# Paciente [24] a finalizado la consulta a las 159.00.
# Al paciente:  24  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  24  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  25  tiempo de salida:  165
# Paciente [25] a finalizado la consulta a las 165.00.
# Al paciente:  25  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  25  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 28 a la hora 166.00.
# El paciente se termino de atender:  26  tiempo de salida:  171
# Paciente [26] a finalizado la consulta a las 171.00.
# Al paciente:  26  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente:  26  pasa a un estado ROJO
# El paciente  26 adulto pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  27  tiempo de salida:  174
# Ingreso del paciente con Covid-19 29 a la hora 174.00.
# Paciente [27] a finalizado la consulta a las 174.00.
# Al paciente:  27  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  27 adulto mayor fallece
# Ingreso del paciente con Covid-19 30 a la hora 179.00.
# Ingreso del paciente con Covid-19 31 a la hora 183.00.
# El paciente se termino de atender:  28  tiempo de salida:  184
# Paciente [28] a finalizado la consulta a las 184.00.
# Al paciente:  28  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  28  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 32 a la hora 190.00.
# El paciente se termino de atender:  29  tiempo de salida:  191
# Paciente [29] a finalizado la consulta a las 191.00.
# Al paciente:  29  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  29 adulto mayor fallece
# El paciente se termino de atender:  30  tiempo de salida:  197
# Ingreso del paciente con Covid-19 33 a la hora 197.00.
# Paciente [30] a finalizado la consulta a las 197.00.
# Al paciente:  30  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  30 adulto mayor fallece
# El paciente se termino de atender:  31  tiempo de salida:  198
# Paciente [31] a finalizado la consulta a las 198.00.
# El niño no tiene COVID-19: 31
# Ingreso del paciente con Covid-19 34 a la hora 201.00.
# El paciente se termino de atender:  32  tiempo de salida:  205
# Paciente [32] a finalizado la consulta a las 205.00.
# Al paciente:  32  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  32 adulto mayor fallece
# Ingreso del paciente con Covid-19 35 a la hora 206.00.
# Ingreso del paciente con Covid-19 36 a la hora 213.00.
# El paciente se termino de atender:  33  tiempo de salida:  215
# Paciente [33] a finalizado la consulta a las 215.00.
# Al paciente:  33  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  33  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# El paciente se termino de atender:  34  tiempo de salida:  216
# Paciente [34] a finalizado la consulta a las 216.00.
# Al paciente:  34  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  34  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 37 a la hora 221.00.
# El paciente se termino de atender:  35  tiempo de salida:  223
# Paciente [35] a finalizado la consulta a las 223.00.
# Al paciente:  35  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  35  adulto mayor pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 38 a la hora 226.00.
# El paciente se termino de atender:  36  tiempo de salida:  228
# Paciente [36] a finalizado la consulta a las 228.00.
# Al paciente:  36  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  36 adulto mayor fallece
# Ingreso del paciente con Covid-19 39 a la hora 231.00.
# El paciente se termino de atender:  37  tiempo de salida:  237
# Paciente [37] a finalizado la consulta a las 237.00.
# Al paciente:  37  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente:  37  pasa a un estado ROJO
# El paciente  37 adulto fallece
# Ingreso del paciente con Covid-19 40 a la hora 238.00.
# El paciente se termino de atender:  38  tiempo de salida:  241
# Paciente [38] a finalizado la consulta a las 241.00.
# Al paciente:  38  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  38 adulto mayor fallece
# Ingreso del paciente con Covid-19 41 a la hora 244.00.
# El paciente se termino de atender:  39  tiempo de salida:  247
# Paciente [39] a finalizado la consulta a las 247.00.
# Al paciente:  39  adulto  en estado AMARILLO se le asigna una CAMA
# El paciente:  39  pasa a un estado ROJO
# El paciente  39 adulto pasa a un estado VERDE y se recupera de COVID-19
# Ingreso del paciente con Covid-19 42 a la hora 249.00.
# El paciente se termino de atender:  40  tiempo de salida:  255
# Paciente [40] a finalizado la consulta a las 255.00.
# El niño no tiene COVID-19: 40
# Ingreso del paciente con Covid-19 43 a la hora 257.00.
# El paciente se termino de atender:  41  tiempo de salida:  261
# Ingreso del paciente con Covid-19 44 a la hora 261.00.
# Paciente [41] a finalizado la consulta a las 261.00.
# Al paciente:  41  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  41 adulto mayor fallece
# El paciente se termino de atender:  42  tiempo de salida:  267
# Paciente [42] a finalizado la consulta a las 267.00.
# Al paciente:  42  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  42 adulto mayor fallece
# Ingreso del paciente con Covid-19 45 a la hora 268.00.
# Ingreso del paciente con Covid-19 46 a la hora 274.00.
# El paciente se termino de atender:  43  tiempo de salida:  275
# Paciente [43] a finalizado la consulta a las 275.00.
# Al paciente:  43  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  43 adulto mayor fallece
# El paciente se termino de atender:  44  tiempo de salida:  280
# Ingreso del paciente con Covid-19 47 a la hora 280.00.
# Paciente [44] a finalizado la consulta a las 280.00.
# Al paciente:  44  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  44 adulto mayor fallece
# El paciente se termino de atender:  45  tiempo de salida:  283
# Paciente [45] a finalizado la consulta a las 283.00.
# Al paciente:  45  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  45 adulto mayor fallece
# Ingreso del paciente con Covid-19 48 a la hora 285.00.
# El paciente se termino de atender:  46  tiempo de salida:  289
# Paciente [46] a finalizado la consulta a las 289.00.
# Al paciente:  46  adulto mayor en estado ROJO se le asigna una CAMA
# El paciente  46 adulto mayor fallece
# Ingreso del paciente con Covid-19 49 a la hora 290.00.
# Ingreso del paciente con Covid-19 50 a la hora 296.00.
# El paciente se termino de atender:  47  tiempo de salida:  298
# Paciente [47] a finalizado la consulta a las 298.00.
# El niño no tiene COVID-19: 47
# Adultos mayores fallecidas:
# {47: 1, 66: 1, 131: 1, 151: 1, 174: 1, 191: 1, 197: 1, 205: 1, 228: 1, 241: 1, 261: 1, 267: 1, 275: 1, 280: 1, 283: 1, 289: 1}
# Adultos fallecidos:
# {19: 1, 81: 1, 237: 1}
# Niños fallecidos:
# {108: 1}

# %%
datos=sorted(adultoM_fallecidas.items())
x, y =zip(*datos)
pp.plot(x,y,linewidth=2,color='red')
pp.scatter(x,y,color='blue')
pp.grid(True)
print("Adultos mayores")
pp.show()
# Out:
# Adultos mayores

# %%
datos=sorted(adulto_fallecidas.items())
x, y =zip(*datos)
pp.plot(x,y,linewidth=2,color='red')
pp.scatter(x,y,color='blue')
pp.grid(True)
print("Adultos")
pp.show()
# Out:
# Adultos

# %%
datos=sorted(ninio_fallecidas.items())
x, y =zip(*datos)
pp.plot(x,y,linewidth=2,color='red')
pp.scatter(x,y,color='blue')
pp.grid(True)
print("Niños")
pp.show()
# Out:
# Niños
